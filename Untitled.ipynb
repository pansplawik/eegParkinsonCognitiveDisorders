# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import csv

# %%
df = pd.read_csv('C:/Users/splaw/OneDrive/Pulpit/dyplom/eegParkinsonCognitiveDisorders/dataset.csv', sep=';')

# %%
df
# Out:
#         ID  Plec  Wiek  PD  PD_czas_trwania  Strona_prawa  Strona_lewa  UPDRS  \
# 0    PD129     2    57   1               10           1.0          0.0   42.0
# 1    PD130     2    70   0                5           0.0          1.0   53.0
# 2    PD131     1    73   2               14           0.0          0.0   61.0
# 3    PD132     2    72   1               20           1.0          0.0   51.0
# 4    PD133     2    43   0                7           0.0          1.0   43.0
# ..     ...   ...   ...  ..              ...           ...          ...    ...
# 103  PD235     1    69   2                7           1.0          0.0   67.0
# 104  PD236     2    81   2               11           1.0          1.0   63.0
# 105  PD237     1    72   0               22           0.0          1.0   55.0
# 106  PD238     2    71   1               12           1.0          0.0   46.0
# 107  PD239     1    81   2               15           1.0          0.0   82.0
#
# ...

# %%
plec = df.groupby('PD').size().reset_index(name='liczba osób')

# %%
plec
# Out:
#    PD  liczba osób
# 0   0           47
# 1   1           33
# 2   2           28

# %%
pd = df.groupby(['Plec','PD']).size()
pd
# Out:
# Plec  PD
# 1     0     18
#       1     13
#       2     16
# 2     0     29
#       1     20
#       2     12
# dtype: int64

# %%
pdd=pd.groupby('Plec').size().reset_index(name='liczba osób')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pdd=pd.groupby('Plec').size().reset_index(name='liczba osób')
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:2076, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    2073     raise TypeError("You have to supply one of 'by' and 'level'")
#    2074 axis = self._get_axis_number(axis)
# -> 2076 return SeriesGroupBy(
#    2077     obj=self,
#    2078     keys=by,
#    2079     axis=axis,
#    2080     level=level,
#    2081     as_index=as_index,
#    2082     sort=sort,
#    2083     group_keys=group_keys,
#    2084     squeeze=squeeze,
#    2085     observed=observed,
#    2086     dropna=dropna,
#    2087 )
#
# ...

# %%
pd = df.groupby('PD')['Wiek'].mean()
pd
# Out:
# PD
# 0    62.063830
# 1    68.757576
# 2    71.964286
# Name: Wiek, dtype: float64

# %%
# Importuj bibliotekę pandas, jeśli jeszcze tego nie zrobiłeś
import pandas as pd

# Zakładając, że 'df' to twoja ramka danych

# Najpierw oblicz sumę 'Plec' dla każdej unikalnej wartości w kolumnie 'PD'
pd_sum = df.groupby('PD')['Plec'].sum().reset_index()

# Następnie możesz obliczyć sumę 'Plec' w zależności od płci
sum_by_gender = pd_sum.groupby('Plec').sum()

# Wynik zostanie zwrócony w formie serii (Series) Pandas
sum_by_gender
# Out:
#       PD
# Plec
# 40     2
# 53     1
# 76     0
